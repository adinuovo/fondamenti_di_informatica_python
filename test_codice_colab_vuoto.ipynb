# %% [markdown]
# # Notebook di esercitazione Python
#
# Questo notebook può essere usato per **esercitarsi con il codice Python** in modo semplice e pratico.
#
# Puoi usarlo per:
# - provare piccoli esempi di codice;
# - svolgere esercizi;
# - testare funzioni, variabili, cicli e condizioni;
# - annotare spiegazioni o appunti nelle celle di testo.
#
# Se stai usando **Google Colab**, puoi eseguire ogni cella con il pulsante **Play** oppure con **Shift + Invio**.
#
# Buona esercitazione!
